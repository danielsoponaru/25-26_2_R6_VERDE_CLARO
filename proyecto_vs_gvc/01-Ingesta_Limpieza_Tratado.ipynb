# %%
# Librerias y Warnings
from packages.Preprocesamiento.funciones_limpieza import cargar_datos_raw, ejecutar_pipeline_limpieza
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='pandas')

# %%
# Funcion de carga de datos

ruta_csv = "Datos/Originales/cancellation_data_for_mondragon_unibertsitatea_2024.csv"

df_original = cargar_datos_raw(ruta_csv)
# Out:
# --- Cargando archivo desde: Datos/Originales/cancellation_data_for_mondragon_unibertsitatea_2024.csv ---
# -> Carga exitosa. Filas cargadas: 56448

# %%
# Funcion de limpieza, nuevas variables y prints finales.

if df_original is not None:
    df_final = ejecutar_pipeline_limpieza(df_original, "Datos/Transformados/Limpios/datos_limpios.csv")
    
    print("\nPrimeras filas del DF Limpio:")
    print(df_final.head())
    print("\nInfo del DF Limpio:")
    print(df_final.info())
# Out:
# ========================================
# INICIANDO PROCESO DE LIMPIEZA Y TRANSFORMACIÓN
# ========================================
#
# [EXPORTACIÓN] -> Archivo guardado exitosamente en: Datos/Transformados/Limpios/datos_limpios.csv
# PROCESO COMPLETADO. DataFrame Final: 51743 filas.
#
# Primeras filas del DF Limpio:
#             booked_at        checkin_time       checkout_time  lead_time  \
# 0 2022-11-26 16:10:00 2023-01-01 12:00:00 2023-01-02 12:00:00         36
# 1 2022-12-21 17:27:00 2023-01-01 13:09:00 2023-01-10 12:00:00         11
# 2 2022-09-21 19:46:00 2023-01-01 15:00:00 2023-01-07 12:00:00        102
# 3 2022-09-24 12:09:00 2023-01-01 15:00:00 2023-01-02 12:00:00         99
# 4 2022-10-18 07:12:00 2023-01-01 15:00:00 2023-01-02 12:00:00         75
#
#    lenght_of_stay  checkin_month  checkin_day  adult_count  child_count  \
# 0               1              1            7            1            0
# 1               9              1            7            1            0
# 2               6              1            7            2            4
# 3               1              1            7            2            2
# 4               1              1            7            4            0
#
#             origin  ... reservation_net_value total_adr       status  \
# 0  channel_manager  ...                 15.92     15.92  checked_out
# 1  channel_manager  ...                117.78     13.09  checked_out
# 2  channel_manager  ...                755.65    125.94  checked_out
# 3  channel_manager  ...                186.37    186.37  checked_out
# 4  channel_manager  ...                 77.02     77.02  checked_out
#
#   cancelled_at cancellation_reason cancellation_lead_time is_cancelled  \
# 0          NaT                 NaN                    NaN            0
# 1          NaT                 NaN                    NaN            0
# 2          NaT                 NaN                    NaN            0
# 3          NaT                 NaN                    NaN            0
# 4          NaT                 NaN                    NaN            0
#
#    days_before_checkin days_before_cancel stay_length
# 0                   35                NaN           1
# 1                   10                NaN           8
# 2                  101                NaN           5
# 3                   99                NaN           0
# 4                   75                NaN           0
#
# [5 rows x 40 columns]
#
# Info del DF Limpio:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51743 entries, 0 to 56447
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   booked_at                     51743 non-null  datetime64[ns]
#  1   checkin_time                  51743 non-null  datetime64[ns]
#  2   checkout_time                 51743 non-null  datetime64[ns]
#  3   lead_time                     51743 non-null  int64
#  4   lenght_of_stay                51743 non-null  int64
#  5   checkin_month                 51743 non-null  int64
#  6   checkin_day                   51743 non-null  int64
#  7   adult_count                   51743 non-null  int64
#  8   child_count                   51743 non-null  int64
#  9   origin                        51743 non-null  object
#  10  travel_agency_name            36210 non-null  object
#  11  requested_category            51743 non-null  object
#  12  requested_category_name       51743 non-null  object
#  13  asset                         51743 non-null  object
#  14  asset_type                    51743 non-null  object
#  15  brand                         51743 non-null  object
#  16  asset_opening_date            51743 non-null  datetime64[ns]
#  17  available_units               51743 non-null  int64
#  18  business_segment              51743 non-null  object
#  19  rate                          51743 non-null  object
#  20  rate_group_name               51743 non-null  object
#  21  rate_type                     51743 non-null  object
#  22  completed_entry_forms_count   49927 non-null  float64
#  23  all_entry_forms_completed     51743 non-null  object
#  24  last_entry_form_completed_at  39305 non-null  datetime64[ns]
#  25  returning_inhabitant          51743 non-null  object
#  26  recurrence                    51743 non-null  int64
#  27  libere_community              51743 non-null  object
#  28  bought_products               51743 non-null  object
#  29  product_count                 51743 non-null  int64
#  30  reservation_net_value         51743 non-null  float64
#  31  total_adr                     51743 non-null  float64
#  32  status                        51743 non-null  object
#  33  cancelled_at                  12156 non-null  datetime64[ns]
#  34  cancellation_reason           12156 non-null  object
#  35  cancellation_lead_time        12156 non-null  float64
#  36  is_cancelled                  51743 non-null  int64
#  37  days_before_checkin           51743 non-null  int64
#  38  days_before_cancel            12156 non-null  float64
#  39  stay_length                   51743 non-null  int64
# dtypes: datetime64[ns](6), float64(5), int64(12), object(17)
# memory usage: 16.2+ MB
# None

# %%
df_final
# Out:
#                 booked_at        checkin_time       checkout_time  lead_time  \
# 0     2022-11-26 16:10:00 2023-01-01 12:00:00 2023-01-02 12:00:00         36
# 1     2022-12-21 17:27:00 2023-01-01 13:09:00 2023-01-10 12:00:00         11
# 2     2022-09-21 19:46:00 2023-01-01 15:00:00 2023-01-07 12:00:00        102
# 3     2022-09-24 12:09:00 2023-01-01 15:00:00 2023-01-02 12:00:00         99
# 4     2022-10-18 07:12:00 2023-01-01 15:00:00 2023-01-02 12:00:00         75
# ...                   ...                 ...                 ...        ...
# 56443 2023-10-13 13:38:00 2023-12-31 15:00:00 2024-01-01 11:00:00         79
# 56444 2023-10-13 13:38:00 2023-12-31 15:00:00 2024-01-01 11:00:00         79
# 56445 2023-10-17 08:36:00 2023-12-31 15:00:00 2024-01-01 11:00:00         75
# 56446 2023-10-17 08:36:00 2023-12-31 15:00:00 2024-01-01 11:00:00         75
# 56447 2023-12-30 08:02:00 2023-12-31 15:00:00 2024-01-02 11:00:00          1
#
#        lenght_of_stay  checkin_month  checkin_day  adult_count  child_count  \
# 0                   1              1            7            1            0
# 1                   9              1            7            1            0
# 2                   6              1            7            2            4
# 3                   1              1            7            2            2
# 4                   1              1            7            4            0
# ...               ...            ...          ...          ...          ...
# 56443               1             12            7            4            0
# 56444               1             12            7            4            0
# 56445               1             12            7            5            0
# 56446               1             12            7            4            0
# 56447               2             12            7            2            0
#
#                 origin  ... reservation_net_value total_adr       status  \
# 0      channel_manager  ...                 15.92     15.92  checked_out
# 1      channel_manager  ...                117.78     13.09  checked_out
# 2      channel_manager  ...                755.65    125.94  checked_out
# 3      channel_manager  ...                186.37    186.37  checked_out
# 4      channel_manager  ...                 77.02     77.02  checked_out
# ...                ...  ...                   ...       ...          ...
# 56443        telephone  ...                169.60    169.60  checked_out
# 56444        telephone  ...                169.60    169.60  checked_out
# 56445   direct_channel  ...                647.28    647.28  checked_out
# 56446   direct_channel  ...                732.73    732.73  checked_out
# 56447   direct_channel  ...                343.64    171.82    cancelled
#
#              cancelled_at cancellation_reason cancellation_lead_time  \
# 0                     NaT                 NaN                    NaN
# 1                     NaT                 NaN                    NaN
# 2                     NaT                 NaN                    NaN
# 3                     NaT                 NaN                    NaN
# 4                     NaT                 NaN                    NaN
# ...                   ...                 ...                    ...
# 56443                 NaT                 NaN                    NaN
# 56444                 NaT                 NaN                    NaN
# 56445                 NaT                 NaN                    NaN
# 56446                 NaT                 NaN                    NaN
# 56447 2023-12-30 12:44:00       force_majeure                    0.0
#
#       is_cancelled  days_before_checkin days_before_cancel stay_length
# 0                0                   35                NaN           1
# 1                0                   10                NaN           8
# 2                0                  101                NaN           5
# 3                0                   99                NaN           0
# 4                0                   75                NaN           0
# ...            ...                  ...                ...         ...
# 56443            0                   79                NaN           0
# 56444            0                   79                NaN           0
# 56445            0                   75                NaN           0
# 56446            0                   75                NaN           0
# 56447            1                    1                0.0           1
#
# [51743 rows x 40 columns]
