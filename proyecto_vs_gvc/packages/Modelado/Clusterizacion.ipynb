# %%
import os
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(os.path.join('..', '..', 'Datos', 'Transformados', 'df_meteorologico.csv'), index_col = 0)

# %%
df
# Out:
#                  booked_at         checkin_time        checkout_time  \
# 0      2022-11-26 16:10:00  2023-01-01 12:00:00  2023-01-02 12:00:00
# 1      2022-12-21 17:27:00  2023-01-01 13:09:00  2023-01-10 12:00:00
# 2      2022-09-21 19:46:00  2023-01-01 15:00:00  2023-01-07 12:00:00
# 3      2022-09-24 12:09:00  2023-01-01 15:00:00  2023-01-02 12:00:00
# 4      2022-10-18 07:12:00  2023-01-01 15:00:00  2023-01-02 12:00:00
# ...                    ...                  ...                  ...
# 53792  2023-10-13 13:38:00  2023-12-31 15:00:00  2024-01-01 11:00:00
# 53793  2023-10-13 13:38:00  2023-12-31 15:00:00  2024-01-01 11:00:00
# 53794  2023-10-17 08:36:00  2023-12-31 15:00:00  2024-01-01 11:00:00
# 53795  2023-10-17 08:36:00  2023-12-31 15:00:00  2024-01-01 11:00:00
# 53796  2023-12-30 08:02:00  2023-12-31 15:00:00  2024-01-02 11:00:00
#
#        lead_time  lenght_of_stay  checkin_month  checkin_day  adult_count  \
# 0             36               1              1            7            1
# 1             11               9              1            7            1
# 2            102               6              1            7            2
# 3             99               1              1            7            2
# 4             75               1              1            7            4
# ...          ...             ...            ...          ...          ...
# 53792         79               1             12            7            4
# 53793         79               1             12            7            4
# 53794         75               1             12            7            5
# 53795         75               1             12            7            4
# 53796          1               2             12            7            2
#
#        child_count           origin  ... MEAN_racha STD_racha MIN_hrMedia  \
# 0                0  channel_manager  ...  21.100000  0.000000        30.0
# 1                0  channel_manager  ...  14.633333  7.479008        30.0
# 2                4  channel_manager  ...  11.516667  6.934074        30.0
# 3                2  channel_manager  ...  21.100000  0.000000        30.0
# 4                0  channel_manager  ...  21.100000  0.000000        30.0
# ...            ...              ...  ...        ...       ...         ...
# 53792            0        telephone  ...   8.300000  0.000000        76.0
# 53793            0        telephone  ...   8.300000  0.000000        76.0
# 53794            0   direct_channel  ...   8.300000  0.000000        76.0
# 53795            0   direct_channel  ...   8.300000  0.000000        76.0
# 53796            0   direct_channel  ...   7.050000  1.250000        76.0
#
#       Q1_hrMedia Q2_hrMedia Q3_hrMedia MAX_hrMedia  IQR_hrMedia MEAN_hrMedia  \
# 0          30.00       30.0      30.00        30.0          0.0    30.000000
# 1          65.00       75.0      82.00        89.0         17.0    70.777778
# 2          66.75       73.5      80.25        85.0         13.5    68.166667
# 3          30.00       30.0      30.00        30.0          0.0    30.000000
# 4          30.00       30.0      30.00        30.0          0.0    30.000000
# ...          ...        ...        ...         ...          ...          ...
# 53792      76.00       76.0      76.00        76.0          0.0    76.000000
# 53793      76.00       76.0      76.00        76.0          0.0    76.000000
# 53794      76.00       76.0      76.00        76.0          0.0    76.000000
# 53795      76.00       76.0      76.00        76.0          0.0    76.000000
# 53796      76.00       76.0      76.00        76.0          0.0    76.000000
#
#       STD_hrMedia
# 0        0.000000
# 1       17.293401
# 2       18.270346
# 3        0.000000
# 4        0.000000
# ...           ...
# 53792    0.000000
# 53793    0.000000
# 53794    0.000000
# 53795    0.000000
# 53796    0.000000
#
# [53797 rows x 107 columns]
