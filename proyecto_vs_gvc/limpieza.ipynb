# %%
import pandas as pd
import numpy as np
import warnings

# --- CONFIGURACIÓN ---
warnings.filterwarnings("ignore", category=UserWarning, module='pandas')

# 1. CARGA DE DATOS
df = pd.read_csv(r"Datos\Originales\cancellation_data_for_mondragon_unibertsitatea_2024.csv")

# 2. LIMPIEZA DE COLUMNAS
df.columns = (
    df.columns.str.strip()
    .str.lower()
    .str.replace(" ", "_")
    .str.replace(r"[^\w_]", "", regex=True)
)

# 3. ELIMINAR DUPLICADOS
df = df.drop_duplicates()

# ---------------------------------------------------------
# 4. FILTROS Y CONTEOS (RAW DATA)
# ---------------------------------------------------------

# A) Eliminar valores menores a 0 en lead_time
if "lead_time" in df.columns:
    df = df[df["lead_time"] >= 0]

# B) Gestionar lenght_of_stay
col_stay = "lenght_of_stay" if "lenght_of_stay" in df.columns else "length_of_stay"

if col_stay in df.columns:
    # 1. Contar 0s
    count_stay_0 = (df[col_stay] == 0).sum()
    print(f"Instancias con {col_stay} == 0 encontradas: {count_stay_0}")
    
    # 2. MOSTRAR ESOS CASOS (para observar)
    casos_estancia_0 = df[df[col_stay] == 0]
    if not casos_estancia_0.empty:
        print(f"\n--- Muestra de {col_stay} == 0 (se van a eliminar): ---")
        print(casos_estancia_0.head()) # Muestra las primeras filas
    
    # 3. ELIMINAR LOS CASOS == 0 DEL DF ORIGINAL
    df = df[df[col_stay] != 0]
    print("-> Se han eliminado las filas con estancia igual a 0.")

    # 4. Eliminar estancias superiores a 30 días
    df = df[df[col_stay] <= 30]
    print(f"-> Se han filtrado las filas con {col_stay} > 30.")

# C) Gestionar adult_count
if "adult_count" in df.columns:
    count_adult_0 = (df["adult_count"] == 0).sum()
    print(f"Instancias con adult_count == 0 encontradas: {count_adult_0}")
    
    # --- NUEVO: CREAR DF Y MOSTRAR PARA OBSERVAR ---
    casos_adultos_0 = df[df["adult_count"] == 0].copy()
    
    if not casos_adultos_0.empty:
        print("\n--- Casos con adult_count == 0 (DataFrame creado para observar): ---")
        print(casos_adultos_0)
        print("--------------------------------------------------------------------\n")
    
    # df = df[df["adult_count"] != 0]

# ---------------------------------------------------------
# 5. CONVERSIÓN DE FECHAS
# ---------------------------------------------------------
columnas_fecha = [
    "booked_at", 
    "checkin_time", 
    "checkout_time", 
    "cancelled_at", 
    "asset_opening_date"
]

for col in columnas_fecha:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col], errors="coerce")

# ---------------------------------------------------------
# 6. MAPEOS Y VARIABLES CATEGÓRICAS
# ---------------------------------------------------------
month_map = {
    "January": 1, "February": 2, "March": 3, "April": 4,
    "May": 5, "June": 6, "July": 7, "August": 8,
    "September": 9, "October": 10, "November": 11, "December": 12
}

day_map = {
    "Monday": 1, "Tuesday": 2, "Wednesday": 3,
    "Thursday": 4, "Friday": 5, "Saturday": 6, "Sunday": 7
}

if "checkin_month" in df.columns:
    df["checkin_month"] = df["checkin_month"].map(month_map)

if "checkin_day" in df.columns:
    df["checkin_day"] = df["checkin_day"].map(day_map)

categoricas = [
    "channel", "reservation_status", "room_type", "payment_method",
    "property_name", "country"
]

for col in categoricas:
    if col in df.columns:
        df[col] = df[col].astype(str).str.lower().str.strip()

# ---------------------------------------------------------
# 7. INGENIERÍA DE VARIABLES
# ---------------------------------------------------------
df["is_cancelled"] = df["cancelled_at"].notna().astype(int)

df["fecha_incoherente"] = False
df.loc[df["checkout_time"] < df["checkin_time"], "fecha_incoherente"] = True
df.loc[df["cancelled_at"] < df["booked_at"], "fecha_incoherente"] = True

df = df[df["fecha_incoherente"] == False]

df["days_before_checkin"] = (
    df["checkin_time"] - df["booked_at"]
).where(df["checkin_time"].notna() & df["booked_at"].notna()).dt.days

df["days_before_cancel"] = (
    df["cancelled_at"] - df["booked_at"]
).dt.days

df["stay_length"] = (
    df["checkout_time"] - df["checkin_time"]
).dt.days

# ---------------------------------------------------------
# 8. FILTROS FINALES (Outliers y Limpieza)
# ---------------------------------------------------------
# Filtrar outliers de days_before_checkin (-1 a 450 días)
df = df.loc[(df["days_before_checkin"] <= 450) & (df["days_before_checkin"] >= -1)].copy()

# Eliminar columna auxiliar
df = df.drop(columns=["fecha_incoherente"])
# Out:
# Instancias con lenght_of_stay == 0 encontradas: 1
#
# --- Muestra de lenght_of_stay == 0 (se van a eliminar): ---
#                  booked_at         checkin_time        checkout_time  \
# 23009  Oct 27, 2023, 01:46  Oct 27, 2023, 04:07  Oct 27, 2023, 11:00
#
#        lead_time  lenght_of_stay checkin_month checkin_day  adult_count  \
# 23009          0               0       October      Friday            2
#
#        child_count     origin  ... recurrence libere_community  \
# 23009            0  telephone  ...          1              yes
#
#       bought_products product_count reservation_net_value total_adr  \
# 23009              no             0                     0       NaN
#
#             status  cancelled_at cancellation_reason cancellation_lead_time
# 23009  checked_out           NaN                 NaN                    NaN
#
# [1 rows x 36 columns]
# -> Se han eliminado las filas con estancia igual a 0.
# -> Se han filtrado las filas con lenght_of_stay > 30.
# Instancias con adult_count == 0 encontradas: 42
#
# --- Casos con adult_count == 0 (DataFrame creado para observar): ---
#                  booked_at         checkin_time        checkout_time  \
# 2317    Apr 7, 2023, 11:29  Apr 11, 2023, 15:00  Apr 13, 2023, 12:00
# 2418    Nov 8, 2022, 10:42  Apr 15, 2023, 15:00  Apr 16, 2023, 12:00
# 2430   Mar 16, 2023, 14:32  Apr 15, 2023, 15:00  Apr 16, 2023, 12:00
# 2435   Mar 16, 2023, 14:32  Apr 15, 2023, 15:00  Apr 16, 2023, 12:00
# 2440    Apr 4, 2023, 10:12  Apr 15, 2023, 15:00  Apr 16, 2023, 12:00
# 4697    Apr 7, 2023, 14:30  Jun 13, 2023, 15:00  Jun 15, 2023, 12:00
# 5091    Feb 8, 2023, 14:53  Jun 22, 2023, 15:00  Jun 23, 2023, 12:00
# 8486             4           email  ...          1               no
# 8488             5           email  ...          1               no
# 8497             6           email  ...          1               no
# 8696             1  direct_channel  ...          1               no
# 9746             1  direct_channel  ...          1               no
# 10126            1  direct_channel  ...          1               no
# 10127            1  direct_channel  ...          1               no
# 10299            1  direct_channel  ...          1               no
# 10311            1  direct_channel  ...          3               no
# 10918            1  direct_channel  ...          1               no
# 11706            1  direct_channel  ...          2               no
# 19227            4  direct_channel  ...          1              yes
# 45591            1  direct_channel  ...          1               no
# 45593            1  direct_channel  ...          3               no
# 46699            1  direct_channel  ...          2               no
# 47721            1  direct_channel  ...          2               no
# 48104            1  direct_channel  ...          1               no
# 48105            1  direct_channel  ...          2               no
# 48107            1  direct_channel  ...          4               no
# 48364            1  direct_channel  ...          1               no
# 48366            1  direct_channel  ...          3               no
# 48652            1  direct_channel  ...          3               no
#
#       bought_products product_count reservation_net_value total_adr  \
# 2317               no             0                 63.22     31.61
# 2418              yes             2                354.24    354.24
# 2430              yes             2                435.46    435.46
# 2435              yes             2                339.09    339.09
# 2440              yes             2                117.27    117.27
# 4697               no             0                 98.62     49.31
# 5091              yes             2                292.73    292.73
# 5092              yes             2                317.27    317.27
# 5098              yes             2                317.27    317.27
# 5101              yes             2                434.55    434.55
# 5110              yes             2                317.27    317.27
# 5445              yes             7               1,832.7    305.45
# 6272               no             0                 43.36     43.36
# 6509               no             0                 41.82     41.82
# 6701               no             0                 45.98     45.98
# 7292               no             0                100.69    100.69
# 7293               no             0               -268.49   -268.49
# 7756               no             0                 -3.83     -3.83
# 8480              yes             2                587.26    293.63
# 8482              yes             2                814.54    407.27
# 8486              yes             2                   440       220
# 8488              yes             2                   600       300
# 8497              yes             2                632.72    316.36
# 8696               no             0                    23        23
# 9746               no             0                 20.45     20.45
# 10126              no             0                  21.6      21.6
# 10127              no             0                  21.6      21.6
# 10299              no             0                 16.82     16.82
# 10311              no             0                 23.82     23.82
# 10918              no             0                 27.27     27.27
# 11706              no             0                105.55    105.55
# 19227              no             0                 75.27     75.27
# 45591              no             0                 27.36     27.36
# 45593              no             0                 27.36     27.36
# 46699              no             0                 50.27     25.14
# 47721              no             0                  16.9      16.9
# 48104              no             0                 29.54     29.54
# 48105              no             0                 29.54     29.54
# 48107              no             0                 29.54     29.54
# 48364             yes             6                215.24     35.87
# 48366             yes             6                215.24     35.87
# 48652             yes             1                 31.88     31.88
#
#             status         cancelled_at cancellation_reason  \
# 2317     cancelled  Apr 11, 2023, 15:15               other
# 2418   checked_out                  NaN                 NaN
# 2430   checked_out                  NaN                 NaN
# 2435   checked_out                  NaN                 NaN
# 2440   checked_out                  NaN                 NaN
# 4697     cancelled  Jun 11, 2023, 18:44               other
# 5091   checked_out                  NaN                 NaN
# 5092   checked_out                  NaN                 NaN
# 5098   checked_out                  NaN                 NaN
# 5101   checked_out                  NaN                 NaN
# 5110   checked_out                  NaN                 NaN
# 5445   checked_out                  NaN                 NaN
# 6272     cancelled  Jul 21, 2023, 13:58       changed_plans
# 6509   checked_out                  NaN                 NaN
# 6701     cancelled  Jul 31, 2023, 09:24     technical_error
# 7292     cancelled  Aug 13, 2023, 11:43               other
# 7293     cancelled  Aug 13, 2023, 11:43               other
# 7756     cancelled  Aug 24, 2023, 11:38               other
# 8480   checked_out                  NaN                 NaN
# 8482   checked_out                  NaN                 NaN
# 8486   checked_out                  NaN                 NaN
# 8488   checked_out                  NaN                 NaN
# 8497   checked_out                  NaN                 NaN
# 8696     cancelled  Sep 11, 2023, 21:28     technical_error
# 9746   checked_out                  NaN                 NaN
# 10126  checked_out                  NaN                 NaN
# 10127  checked_out                  NaN                 NaN
# 10299  checked_out                  NaN                 NaN
# 10311  checked_out                  NaN                 NaN
# 10918    cancelled  Nov 24, 2023, 15:58       changed_plans
# 11706  checked_out                  NaN                 NaN
# 19227  checked_out                  NaN                 NaN
# 45591  checked_out                  NaN                 NaN
# 45593  checked_out                  NaN                 NaN
# 46699  checked_out                  NaN                 NaN
# 47721  checked_out                  NaN                 NaN
# 48104  checked_out                  NaN                 NaN
# 48105  checked_out                  NaN                 NaN
# 48107  checked_out                  NaN                 NaN
# 48364  checked_out                  NaN                 NaN
# 48366  checked_out                  NaN                 NaN
# 48652  checked_out                  NaN                 NaN
#
#       cancellation_lead_time
# 2317                     4.0
# 2418                     NaN
# 2430                     NaN
# 2435                     NaN
# 2440                     NaN
# 4697                    65.0
# 5091                     NaN
# 5092                     NaN
# 5098                     NaN
# 5101                     NaN
# 5110                     NaN
# 5445                     NaN
# 6272                    34.0
# 6509                     NaN
# 6701                     3.0
# 7292                     6.0
# 7293                     6.0
# 7756                    31.0
# 8480                     NaN
# 8482                     NaN
# 8486                     NaN
# 8488                     NaN
# 8497                     NaN
# 8696                     1.0
# 9746                     NaN
# 10126                    NaN
# 10127                    NaN
# 10299                    NaN
# 10311                    NaN
# 10918                    3.0
# 11706                    NaN
# 19227                    NaN
# 45591                    NaN
# 45593                    NaN
# 46699                    NaN
# 47721                    NaN
# 48104                    NaN
# 48105                    NaN
# 48107                    NaN
# 48364                    NaN
# 48366                    NaN
# 48652                    NaN
#
# [42 rows x 36 columns]
# --------------------------------------------------------------------
# C:\Users\danie\AppData\Local\Temp\ipykernel_11844\1243894190.py:80: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors="coerce")
# C:\Users\danie\AppData\Local\Temp\ipykernel_11844\1243894190.py:80: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors="coerce")
# C:\Users\danie\AppData\Local\Temp\ipykernel_11844\1243894190.py:80: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors="coerce")
# C:\Users\danie\AppData\Local\Temp\ipykernel_11844\1243894190.py:80: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors="coerce")
# C:\Users\danie\AppData\Local\Temp\ipykernel_11844\1243894190.py:80: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors="coerce")

# %%
ruta_destino = 'Datos/Transformados/Limpios/df_limpio.csv'

df.to_csv(ruta_destino, index=False)
